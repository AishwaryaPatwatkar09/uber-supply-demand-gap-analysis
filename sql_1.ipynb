# %%
# !pip install pandasql
import pandas as pd
import pandasql as ps

# Load the data
df = pd.read_csv('/content/Uber Request Data - Cleaned.csv')  # Adjust path if needed

# %%
df.columns
# Out:
# Index(['Request id', 'Pickup point', 'Driver ID', 'Status',
#        'Request timestamp', 'Time slot', 'Drop timestamp', 'Hour'],
#       dtype='object')

# %%
query = """
SELECT [Request timestamp], COUNT(*) as request_count
FROM df
GROUP BY [Request timestamp]
"""
ps.sqldf(query, locals())
# Out:
#      Request timestamp  request_count
# 0     11-07-2016 00:00              1
# 1     11-07-2016 00:02              1
# 2     11-07-2016 00:05              1
# 3     11-07-2016 00:06              1
# 4     11-07-2016 00:09              2
# ...                ...            ...
# 4011  15-07-2016 23:52              1
# 4012  15-07-2016 23:54              1
# 4013  15-07-2016 23:55              1
# 4014  15-07-2016 23:57              2
# 4015  15-07-2016 23:59              2
#
# [4016 rows x 2 columns]

# %%
query = """
SELECT [Time slot], COUNT(*) as cancel_count
FROM df
WHERE Status = 'Cancelled'
GROUP BY [Time slot]
ORDER BY cancel_count DESC
"""
ps.sqldf(query, locals())
# Out:
#        Time slot  cancel_count
# 0        Evening           515
# 1        Morning           259
# 2          Night           202
# 3  Early Morning           184
# 4      Afternoon           104

# %%
query = """
SELECT Status, COUNT(*) as count
FROM df
GROUP BY Status
ORDER BY count DESC
"""
ps.sqldf(query, locals())
# Out:
#               Status  count
# 0     Trip Completed   4640
# 1          Cancelled   1264
# 2  No Cars Available    841

# %%
query = """
SELECT [Pickup point], Status, COUNT(*) as count
FROM df
GROUP BY [Pickup point], Status
ORDER BY [Pickup point], Status
"""
ps.sqldf(query, locals())
# Out:
#   Pickup point             Status  count
# 0      Airport          Cancelled    778
# 1      Airport  No Cars Available    572
# 2      Airport     Trip Completed   1888
# 3         City          Cancelled    486
# 4         City  No Cars Available    269
# 5         City     Trip Completed   2752

# %%
result = ps.sqldf(query, locals())
result.to_csv("Query3_StatusWise.csv", index=False)
